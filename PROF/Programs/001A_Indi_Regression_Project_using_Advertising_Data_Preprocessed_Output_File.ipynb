# %% [markdown]
# **1) Install/ Import the required Python Packages/ Libraries**

# %%
#Import required python packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.metrics import mean_squared_error, r2_score
import warnings
warnings.filterwarnings("ignore")
from sklearn import preprocessing
# %matplotlib inline

# %% [markdown]
# **2) Mounting the Google Drive**

# %% [markdown]
# **3) Read the Data file and check**

# %%
# Read the Diabetes Data from .csv file and check the data shape (number of Rows and Columns)
#df = pd.read_csv('gdrive/My Drive/RRCE-Internship-Demo-Projects/01-Advertising/Data-Files/Train_Advertising_Data.csv')
df = pd.read_csv('C:/MDemo/PROF/Profit-Prediction-Project-in-Anaconda-Files/Data-Files/Train_Advertising_Data.csv')
print(df.shape)
df.head()
# Out:
# (150, 4)
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %% [markdown]
# ##**I) Check and decide the ML Learning Type and sub-type as applicable**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         150 non-null    float64
#  1   Radio      150 non-null    float64
#  2   Newspaper  150 non-null    float64
#  3   Sales      150 non-null    float64
# dtypes: float64(4)
# memory usage: 4.8 KB

# %% [markdown]
# **Observations on the given Dataset:**
# * a) Number of Independet Variables: 12 (Identified)
# * b) Number of Dependent Variable : 1 (Price) (Identified)
# * c) There is no Missing Value in the Dependent Variable column "Price"

# %% [markdown]
# **Conclusions:**
# ###**a) The given dataset probably belongs to the"Supervised Learning" main-type**
# ###**b) Since the Dependent variable values are varying integers in nature, the given dataset is of "Regression" sub-type.**

# %% [markdown]
# ##**II) Check and remove the duplicate records, if any**

# %%
df.shape
# Out:
# (150, 4)

# %%
# Remove all duplicates:
df.drop_duplicates(inplace = True)

# %%
df.shape
# Out:
# (150, 4)

# %% [markdown]
# ###**Conclusion: No Duplicate Record**

# %% [markdown]
# ##**IV) Check for Missing Values and handle them as required**

# %% [markdown]
# **a) Check the Missing Values, if any**

# %%
df.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %% [markdown]
# ##**V) Check for necessity of creating new column(s) and create the columns as required**

# %% [markdown]
# ###**Decision: As of now, there is no necessity to create new column(s).**

# %% [markdown]
# ##**VI) Check the unique Values of each column and observe the following and take actions as required:**
# * **a) Wrong Data in the columns, if any**
# * **b) Wrong format of the data in the columns, if any**
# * **c) Identify the columns which need to be categorically converted to numeric values by using Nominal method/ Ordinal Method**

# %% [markdown]
# ###**Column-1: Emp_ID**

# %%
df['TV']
# Out:
# 0      230.1
# 1       44.5
# 2       17.2
# 3      151.5
# 4      180.8
#        ...
# 145    140.3
# 146    240.1
# 147    243.2
# 148     38.0
# 149     44.7
# Name: TV, Length: 150, dtype: float64

# %%
df['Radio'].value_counts()
# Out:
# Radio
# 43.9    2
# 33.5    2
# 26.7    2
# 49.4    2
# 4.1     2
#        ..
# 22.5    1
# 25.7    1
# 8.4     1
# 33.4    1
# 25.8    1
# Name: count, Length: 134, dtype: int64

# %%
df['Newspaper'].value_counts()
# Out:
# Newspaper
# 9.3     3
# 8.7     2
# 52.9    2
# 25.6    2
# 23.2    2
#        ..
# 35.7    1
# 31.5    1
# 43.3    1
# 26.4    1
# 20.6    1
# Name: count, Length: 135, dtype: int64

# %%
df['Sales'].value_counts()
# Out:
# Sales
# 9.7     4
# 25.4    3
# 15.5    3
# 12.9    3
# 9.5     3
#        ..
# 20.2    1
# 21.2    1
# 22.6    1
# 10.7    1
# 10.3    1
# Name: count, Length: 103, dtype: int64

# %%
df.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  150.000000  150.000000  150.000000  150.000000
# mean   143.488000   24.576667   32.220000   14.150667
# std     86.040345   14.751805   22.422448    5.258879
# min      0.700000    0.000000    0.300000    1.600000
# 25%     69.550000   11.850000   13.375000   10.400000
# 50%    138.550000   26.300000   28.100000   13.050000
# 75%    219.450000   36.825000   45.975000   18.225000
# max    296.400000   49.600000  114.000000   25.400000

# %%
X = df.drop(['Sales'], axis = 1)
Y = df['Sales']
X.head()
# Out:
#       TV  Radio  Newspaper
# 0  230.1   37.8       69.2
# 1   44.5   39.3       45.1
# 2   17.2   45.9       69.3
# 3  151.5   41.3       58.5
# 4  180.8   10.8       58.4

# %%
Y.head()
# Out:
# 0    22.1
# 1    10.4
# 2     9.3
# 3    18.5
# 4    12.9
# Name: Sales, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 66)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (120, 3)
# (120,)
# (30, 3)
# (30,)

# %%
# Fitting Multiple Linear Regression to the Training set
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
model=regressor.fit(X_train, y_train)

# %%
# Calculate the accuracy of learning by the Algorithm
regressor.score(X_train,y_train)
# Out:
# 0.8834998564711629

# %%
train_pred=regressor.predict(X_train)

# %%
# Predicting the Test set results
y_pred = regressor.predict(X_test)

# %%
# Calcualte the accuracy of prediction (y_test Vs y_pred) # This measure is part of Model Evaluation
r2_score(y_test, y_pred)
# Out:
# 0.9379189949986345

# %%
regressor.score(X_test,y_test)
# Out:
# 0.9379189949986345

# %%
# Calculate the Model Error (RMSE) # This measure is also part of Model Evaluation
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
rmse
# Out:
# 1.314673427030651

# %%
Train_Acc=regressor.score(X_train,y_train)
Test_Acc=r2_score(y_test,y_pred)

# %%
print("Training Accuracy :", regressor.score(X_train,y_train))
print("Testing Accuracy :", r2_score(y_test,y_pred))
# Out:
# Training Accuracy : 0.8834998564711629
# Testing Accuracy : 0.9379189949986345

# %%
Train_Err=np.sqrt(mean_squared_error(y_train, train_pred))
Test_Err=np.sqrt(mean_squared_error(y_test, y_pred))

# %%
print("Training Error :", np.sqrt(mean_squared_error(y_train, train_pred)))
print("Testing Error :", np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# Training Error : 1.7858633341727372
# Testing Error : 1.314673427030651

# %% [markdown]
# ##**VIII) Implement the Scaling as required**

# %% [markdown]
# ###**Use Normalization**

# %%
X_train.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper'], dtype='object')

# %%
columnNames=(['TV', 'Radio', 'Newspaper'])

# %%
min_max_scaler_object = preprocessing.MinMaxScaler()
X_train1 = min_max_scaler_object.fit_transform(X_train)
X_train1 = pd.DataFrame(X_train1 , columns = columnNames)
X_train1.head()
# Out:
#          TV     Radio  Newspaper
# 0  0.886710  0.063265   0.164456
# 1  0.027054  0.989796   0.655172
# 2  0.633074  0.342857   0.150309
# 3  0.300981  0.193878   0.307692
# 4  0.719648  0.869388   0.290893

# %%
min_max_scaler_object = preprocessing.MinMaxScaler()
X_test1 = min_max_scaler_object.fit_transform(X_test)
X_test1 = pd.DataFrame(X_test1 , columns = columnNames)
X_test1.head()
# Out:
#          TV     Radio  Newspaper
# 0  0.685992  0.423387   0.288181
# 1  0.073541  0.032258   0.270916
# 2  0.988716  0.580645   0.207171
# 3  0.235798  0.413306   0.239044
# 4  0.786770  1.000000   0.496680

# %%
# Fitting Multiple Linear Regression to the Training set
from sklearn.linear_model import LinearRegression
regressor1 = LinearRegression()
model1=regressor1.fit(X_train1, y_train)

# %%
train_pred1=regressor1.predict(X_train1)

# %%
# Predicting the Test set results
y_pred1 = regressor1.predict(X_test1)

# %%
Train_Acc1=regressor1.score(X_train1,y_train)
Test_Acc1=r2_score(y_test,y_pred1)

# %%
print("Training Accuracy :", regressor1.score(X_train1,y_train))
print("Testing Accuracy :", r2_score(y_test,y_pred1))
# Out:
# Training Accuracy : 0.8834998564711629
# Testing Accuracy : 0.9387806596803661

# %%
Train_Err1=np.sqrt(mean_squared_error(y_train, train_pred1))
Test_Err1=np.sqrt(mean_squared_error(y_test, y_pred1))

# %%
print("Training Error :", np.sqrt(mean_squared_error(y_train, train_pred1)))
print("Testing Error :", np.sqrt(mean_squared_error(y_test, y_pred1)))
# Out:
# Training Error : 1.7858633341727372
# Testing Error : 1.305517921810638

# %% [markdown]
# ###**Use Standardization**

# %%
from sklearn.preprocessing import StandardScaler
std_scaler_object = preprocessing.StandardScaler()
X_train2 = std_scaler_object.fit_transform(X_train)
X_train2 = pd.DataFrame(X_train2 , columns = columnNames)
X_train2.head()
# Out:
#          TV     Radio  Newspaper
# 0  1.336494 -1.441960  -0.589385
# 1 -1.578909  1.621326   1.861174
# 2  0.476324 -0.517576  -0.660032
# 3 -0.649926 -1.010131   0.125913
# 4  0.769929  1.223234   0.042020

# %%
from sklearn.preprocessing import StandardScaler
std_scaler_object = preprocessing.StandardScaler()
X_test2 = std_scaler_object.fit_transform(X_test)
X_test2 = pd.DataFrame(X_test2 , columns = columnNames)
X_test2.head()
# Out:
#          TV     Radio  Newspaper
# 0  0.672677 -0.169501  -0.368463
# 1 -1.327562 -1.539634  -0.430617
# 2  1.661359  0.381377  -0.660110
# 3 -0.797639 -0.204814  -0.545363
# 4  1.001814  1.850385   0.382169

# %%
# Fitting Multiple Linear Regression to the Training set
from sklearn.linear_model import LinearRegression
regressor2 = LinearRegression()
model2=regressor2.fit(X_train2, y_train)

# %%
train_pred2=regressor2.predict(X_train2)

# %%
# Predicting the Test set results
y_pred2 = regressor2.predict(X_test2)

# %%
Train_Acc2=regressor2.score(X_train2,y_train)
Test_Acc2=r2_score(y_test,y_pred2)

# %%
print("Training Accuracy :", regressor2.score(X_train2,y_train))
print("Testing Accuracy :", r2_score(y_test,y_pred2))
# Out:
# Training Accuracy : 0.8834998564711629
# Testing Accuracy : 0.9458377321134712

# %%
Train_Err2=np.sqrt(mean_squared_error(y_train, train_pred2))
Test_Err2=np.sqrt(mean_squared_error(y_test, y_pred2))

# %%
print("Training Error :", np.sqrt(mean_squared_error(y_train, train_pred2)))
print("Testing Error :", np.sqrt(mean_squared_error(y_test, y_pred2)))
# Out:
# Training Error : 1.785863334172737
# Testing Error : 1.2279676783592082

# %%
X1 = df.drop(['Sales'], axis = 1)
Y1 = df['Sales']
X1.head()
# Out:
#       TV  Radio  Newspaper
# 0  230.1   37.8       69.2
# 1   44.5   39.3       45.1
# 2   17.2   45.9       69.3
# 3  151.5   41.3       58.5
# 4  180.8   10.8       58.4

# %%
from sklearn.preprocessing import StandardScaler
std_scaler_object = preprocessing.StandardScaler()
X2 = std_scaler_object.fit_transform(X1)
X2 = pd.DataFrame(X2 , columns = columnNames)
print(X2.shape)
X2.head()
# Out:
# (150, 3)
#          TV     Radio  Newspaper
# 0  1.010016  0.899390   1.654765
# 1 -1.154338  1.001414   0.576349
# 2 -1.472694  1.450315   1.659240
# 3  0.093431  1.137444   1.175966
# 4  0.435110 -0.937026   1.171491

# %%
#min_max_scaler_object = preprocessing.MinMaxScaler()
#X2 = min_max_scaler_object.fit_transform(X1)
#X2 = pd.DataFrame(X2 , columns = columnNames)
#print(X2.shape)
#X2.head()

# %%
df1 = pd.DataFrame(data=X2)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         150 non-null    float64
#  1   Radio      150 non-null    float64
#  2   Newspaper  150 non-null    float64
# dtypes: float64(3)
# memory usage: 3.6 KB

# %%
df1.head()
# Out:
#          TV     Radio  Newspaper
# 0  1.010016  0.899390   1.654765
# 1 -1.154338  1.001414   0.576349
# 2 -1.472694  1.450315   1.659240
# 3  0.093431  1.137444   1.175966
# 4  0.435110 -0.937026   1.171491

# %%
df1 = pd.concat([df1,Y1], axis=1)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         150 non-null    float64
#  1   Radio      150 non-null    float64
#  2   Newspaper  150 non-null    float64
#  3   Sales      150 non-null    float64
# dtypes: float64(4)
# memory usage: 4.8 KB

# %%
df1.head()
# Out:
#          TV     Radio  Newspaper  Sales
# 0  1.010016  0.899390   1.654765   22.1
# 1 -1.154338  1.001414   0.576349   10.4
# 2 -1.472694  1.450315   1.659240    9.3
# 3  0.093431  1.137444   1.175966   18.5
# 4  0.435110 -0.937026   1.171491   12.9

# %%
#from google.colab import files
#df1.to_csv("gdrive/My Drive/RRCE-Internship-Demo-Projects/01-Advertising/Data-Files/Train_Advertising_Data_preprocessed.csv", index = False)

df1.to_csv('C:/MDemo/PROF/Profit-Prediction-Project-in-Anaconda-Files/Data-Files/Train_Advertising_Data_Preprocessed.csv', index= False)

# %%
df2 = pd.DataFrame({
    'Methods': ['Without Scaling','With Normalzation','With Standardization'],
    'Train_acc': [Train_Acc, Train_Acc1, Train_Acc2],
    'Test_acc': [Test_Acc, Test_Acc1, Test_Acc2],
    'Train_Err': [Train_Err, Train_Err1, Train_Err2],
    'Test_Err': [Test_Err, Test_Err1, Test_Err2],
    'Selected Method': ['Not Selected', 'Not Selected', 'Selected']})

df2
# Out:
#                 Methods  Train_acc  Test_acc  Train_Err  Test_Err  \
# 0       Without Scaling     0.8835  0.937919   1.785863  1.314673
# 1     With Normalzation     0.8835  0.938781   1.785863  1.305518
# 2  With Standardization     0.8835  0.945838   1.785863  1.227968
#
#   Selected Method
# 0    Not Selected
# 1    Not Selected
# 2        Selected
